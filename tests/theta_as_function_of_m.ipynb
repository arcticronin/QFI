# %%
import qfi_optimization
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

from importlib import reload
reload(qfi_optimization)

sns.set_palette('Set2')

# %%
n = 6
a_x= 3
h_z_bounds = (0, 7) ### Bounds in which search best lower QFI local maximum
trace_out_index = [np.floor(n / 2)] ### Indexes of the density matrix to trace out
delta = 0.1
derivative_delta = 1e-3
m_max = int(np.floor((2**(n-1))))
m_max = 10 ## a caso, hardcoded 

## m is the variable
DEBUG=True

#results = qfi_optimization.get_best_lower_bound(n, a_x, delta, 1, trace_out_index, derivative_delta, h_z_bounds=h_z_bounds)
#results

# %%
y = np.zeros((m_max, len(np.arange(h_z_bounds[0], h_z_bounds[1], 0.1))))
h_z = np.arange(h_z_bounds[0], h_z_bounds[1], 0.1)

for m in range(1, m_max):
    get_t = qfi_optimization.get_lower_bound(
        n, a_x, delta, m, trace_out_index,
        derivative_delta) 
    y[m,:] = (np.array([get_t(h_z)for h_z in np.arange(h_z_bounds[0], h_z_bounds[1], 0.1)]))

# %%
h_z = np.arange(h_z_bounds[0], h_z_bounds[1], 0.1) 

for m in range(1, 5): # m_max):
    plt.plot(h_z, y[m, :], label=f'm={m}', alpha=0.5)

plt.legend()

print("\noptimal at m=1")
r1 = qfi_optimization.get_best_lower_bound(n, a_x, delta, 1, trace_out_index, derivative_delta, h_z_bounds=h_z_bounds)
print(r1)
plt.hlines(r1.fun, h_z[0], h_z[-1], color='r', alpha=0.4, linestyle='--')

print("\noptimal at m=2")
r2 = qfi_optimization.get_best_lower_bound(n, a_x, delta, 2, trace_out_index, derivative_delta, h_z_bounds=h_z_bounds)
print(r2)
plt.hlines(r2.fun, h_z[0], h_z[-1], color='r', alpha=0.4, linestyle='--')

plt.grid(True, linestyle="--", alpha=0.6)
plt.xlabel("$h_z$")
plt.ylabel("QFI lower bound")
plt.show()
# Out:
# optimal at m=1
#       message: Solution found.
#       success: True
#        status: 0
#           fun: 6.791218210076976
#             x: 2.8405751567503796
#           nit: 10
#          nfev: 10
#  value_at_min: 2.2249500936986517
#  value_at_max: 2.2773457392557535
#
# optimal at m=2
#       message: Solution found.
#       success: True
#        status: 0
#           fun: 9.111617016226957
#             x: 2.8019484638315437
#           nit: 11
#          nfev: 11
#  value_at_min: 4.320721145492711
#  value_at_max: 3.043399076345476

# %%
results = []
for m in range(1, 6):
    result = qfi_optimization.get_best_lower_bound(n, a_x, delta, m, trace_out_index, derivative_delta, h_z_bounds=h_z_bounds)
    results.append(result)
    print(f"\noptimal at m={m}")
    print(result)
    print("\n")
# Out:
# optimal at m=1
#       message: Solution found.
#       success: True
#        status: 0
#           fun: 6.791218210076976
#             x: 2.8405751567503796
#           nit: 10
#          nfev: 10
#  value_at_min: 2.2249500936986517
#  value_at_max: 2.2773457392557535
#
#
#
# optimal at m=2
#       message: Solution found.
#       success: True
#        status: 0
#           fun: 9.111617016226957
#             x: 2.8019484638315437
#           nit: 11
#          nfev: 11
#  value_at_min: 4.320721145492711
#  value_at_max: 3.043399076345476
#
#
#
# optimal at m=3
#       message: Solution found.
#       success: True
#        status: 0
#           fun: 9.111617016226424
#             x: 2.8019484654403626
#           nit: 11
#          nfev: 11
#  value_at_min: 4.320721145492533
#  value_at_max: 3.043399076345121
#
#
#
# optimal at m=4
#       message: Solution found.
#       success: True
#        status: 0
#           fun: 9.11161701622598
#             x: 2.8019484650248523
#           nit: 11
#          nfev: 11
#  value_at_min: 4.3207211454928
#  value_at_max: 3.0433990763452985
#
#
#
# optimal at m=5
#       message: Solution found.
#       success: True
#        status: 0
#           fun: 9.111617016227045
#             x: 2.801948463794223
#           nit: 11
#          nfev: 11
#  value_at_min: 4.320721145492622
#  value_at_max: 3.043399076345476

# %%
x_s = [i.x for i in results]
x_s
# Out:
# [2.8405751567503796,
#  2.8019484638315437,
#  2.8019484654403626,
#  2.8019484650248523,
#  2.801948463794223]

# %%
details = []

for m in range(1,6):
        details.append(qfi_optimization.get_results_for_m_hz(n, a_x, delta, m, trace_out_index, derivative_delta)(x_s[m-1]))

# %%
[print(i["sub_qfi_bound"]) for i in details]
# Out:
# 5.419389349899805
# 5.939113298811448
# 5.939113301479092
# 5.939113300790132
# 5.9391132987494535
# [None, None, None, None, None]

# %%
[print(d) for d in details[0].keys()];
# Out:
# fidelity_truncated
# fidelity_truncated_generalized
# lower_tqfi
# upper_tqfi
# fidelity_true
# qfi_fidelity
# sub_qfi_bound
# super_qfi_bound
# trace_rho
# trace_rho_delta
# purity_rho
# purity_rho_delta
# rank_rho
# rank_rho_delta
# truncated_eigenvalues
# eigenvalues
# QFI_from_SLD

# %%
for m in range(len(details)):
    print(f"\n____________________\n m = {m+1}\n_________________________\n")
    print(f"\neigenvalue list: \n{details[m]["eigenvalues"]}")
    print(f"\ntruncated eigenvalues: \n{details[m]["truncated_eigenvalues"]}")
    print(f"\nsub qfi bound: \n{details[m]["lower_tqfi"]}")
    print(f"\nh_z = {x_s[m]}")
# Out:
# ____________________
#  m = 1
# _________________________
#
#
# eigenvalue list:
# [ 7.70782005e-01  2.29217995e-01  5.36573862e-17  2.93804385e-17
#   2.54961085e-17  8.97779464e-18  6.13976507e-18  3.98211239e-18
#   3.07466618e-18  1.41483927e-18  1.04070415e-18  7.54387391e-19
#   5.89157761e-19  3.23535315e-19  1.94476273e-19  1.32760688e-19
#   2.57122161e-20 -1.40437498e-19 -4.91219014e-19 -7.45679412e-19
#  -8.52269981e-19 -1.22386588e-18 -1.70830922e-18 -2.53460553e-18
#  -2.96669645e-18 -3.88480232e-18 -5.83882803e-18 -8.04174280e-18
#  -1.05377658e-17 -2.55384218e-17 -3.80853210e-17 -1.63672437e-16]
#
# truncated eigenvalues:
# [0.770782]
#
# sub qfi bound:
# (6.791218210076976+1.2940598550772133e-15j)
#
# h_z = 2.8405751567503796
#
# ____________________
#  m = 2
# _________________________
#
#
# eigenvalue list:
# [ 7.56825154e-01  2.43174846e-01  3.51489723e-17  2.70315209e-17
#   1.72197539e-17  8.30027048e-18  6.64092890e-18  3.72424351e-18
#   2.78859878e-18  2.02770558e-18  1.88902630e-18  1.62073838e-18
#   9.71017875e-19  6.29886495e-19  4.99921408e-19  8.07479596e-20
#  -2.99153250e-19 -4.49336850e-19 -7.92025747e-19 -9.65387710e-19
#  -1.20394238e-18 -1.60670750e-18 -2.39954679e-18 -2.79067644e-18
#  -3.94239633e-18 -5.43029502e-18 -6.63038783e-18 -8.61785788e-18
#  -1.47823881e-17 -5.12521243e-17 -6.58941211e-17 -1.44071897e-16]
#
# truncated eigenvalues:
# [0.75682515 0.24317485]
#
# sub qfi bound:
# (9.111617016226957-1.2730738946207428e-15j)
#
# h_z = 2.8019484638315437
#
# ____________________
#  m = 3
# _________________________
#
#
# eigenvalue list:
# [ 7.56825154e-01  2.43174846e-01  1.06744417e-16  6.18431460e-17
#   3.63284144e-17  9.64481226e-18  8.16005571e-18  5.04145238e-18
#   4.24921261e-18  2.37582350e-18  1.87349852e-18  1.73919060e-18
#   1.01105734e-18  7.07530821e-19  4.20762120e-19  1.86852903e-19
#   6.62679133e-20 -2.55087293e-19 -5.24287549e-19 -6.11219149e-19
#  -7.20783000e-19 -1.06550531e-18 -1.49466939e-18 -2.26739497e-18
#  -3.40294514e-18 -3.84631929e-18 -4.86236121e-18 -5.63599266e-18
#  -9.76032645e-18 -1.10263447e-17 -1.85592299e-17 -3.17294435e-17]
#
# truncated eigenvalues:
# [7.56825154e-01 2.43174846e-01 1.06744417e-16]
#
# sub qfi bound:
# (9.111617016226424+2.233904517561868e-15j)
#
# h_z = 2.8019484654403626
#
# ____________________
#  m = 4
# _________________________
#
#
# eigenvalue list:
# [ 7.56825154e-01  2.43174846e-01  5.88099489e-17  3.96895843e-17
#   2.56839013e-17  7.59645903e-18  5.71724319e-18  3.31452516e-18
#   3.04123941e-18  2.24681845e-18  1.49225718e-18  9.27109030e-19
#   6.30541095e-19  4.43440786e-19  1.94873559e-19  1.17753390e-19
#  -2.59905922e-19 -2.67194536e-19 -4.80059861e-19 -6.32222695e-19
#  -1.17719803e-18 -1.34393567e-18 -2.00884787e-18 -3.27144039e-18
#  -3.81708707e-18 -6.81152559e-18 -7.99995872e-18 -8.61473484e-18
#  -1.40391758e-17 -1.94240685e-17 -4.01876608e-17 -1.03826600e-16]
#
# truncated eigenvalues:
# [7.56825154e-01 2.43174846e-01 5.88099489e-17 3.96895843e-17]
#
# sub qfi bound:
# 9.11161701622598
#
# h_z = 2.8019484650248523
#
# ____________________
#  m = 5
# _________________________
#
#
# eigenvalue list:
# [ 7.56825154e-01  2.43174846e-01  1.25817999e-16  4.14561393e-17
#   1.65304743e-17  1.11256784e-17  9.07477381e-18  5.77456582e-18
#   3.17480853e-18  2.80701069e-18  2.19648004e-18  1.49637361e-18
#   1.11150406e-18  8.89550577e-19  5.13413529e-19  8.69411418e-20
#  -8.92004358e-20 -2.91662099e-19 -4.65527594e-19 -8.68822011e-19
#  -1.06938997e-18 -1.35749200e-18 -1.56610787e-18 -2.21646621e-18
#  -3.60623812e-18 -4.13865733e-18 -5.46428001e-18 -7.04027726e-18
#  -9.77255466e-18 -1.61337659e-17 -2.57669724e-17 -4.91064288e-17]
#
# truncated eigenvalues:
# [7.56825154e-01 2.43174846e-01 1.25817999e-16 4.14561393e-17
#  1.65304743e-17]
#
# sub qfi bound:
# (9.111617016227045-1.7395855860259694e-15j)
#
# h_z = 2.801948463794223

# %%
data = []
for m in range(len(details)):
    eigenvalues = np.pad(
        [np.format_float_scientific(val, precision=5) for val in details[m]["eigenvalues"][:5]],
        (0, max(0, 5 - len(details[m]["eigenvalues"]))),
        constant_values="0.0e+00"
    )
    truncated_eigenvalues = np.pad(
        [np.format_float_scientific(val, precision=5) for val in details[m]["truncated_eigenvalues"][:5]],
        (0, max(0, 5 - len(details[m]["truncated_eigenvalues"]))),
        constant_values="0.0e+00"
    )
    
    row = [
        m + 1,  # m index
        *eigenvalues,  # First 5 eigenvalues (or padded with 0)
        *truncated_eigenvalues,  # First 5 truncated eigenvalues (or padded with 0)
        np.format_float_scientific(details[m]["lower_tqfi"], precision=3),  # Sub QFI bound
        np.format_float_scientific(x_s[m], precision=3)  # h_z value
    ]
    data.append(row)

# Define column names
columns = (
    ["m"] +
    [f"eigenvalue_{i+1}" for i in range(5)] +
    [f"truncated_eigenvalue_{i+1}" for i in range(5)] +
    ["lower_tqfi", "h_z"]
)

# Create DataFrame
df = pd.DataFrame(data, columns=columns)
df.to_csv("test_truncation_eigenvalues.csv")
# Display DataFrame
df
# Out:
# /home/ronin/miniforge3/envs/space/lib/python3.12/site-packages/numpy/core/arrayprint.py:1125: ComplexWarning: Casting complex values to real discards the imaginary part
#   return dragon4_scientific(x, precision=precision, unique=unique,
#    m eigenvalue_1 eigenvalue_2 eigenvalue_3 eigenvalue_4 eigenvalue_5  \
# 0  1  7.70782e-01  2.29218e-01  5.36574e-17  2.93804e-17  2.54961e-17
# 1  2  7.56825e-01  2.43175e-01   3.5149e-17  2.70315e-17  1.72198e-17
# 2  3  7.56825e-01  2.43175e-01  1.06744e-16  6.18431e-17  3.63284e-17
# 3  4  7.56825e-01  2.43175e-01  5.88099e-17  3.96896e-17  2.56839e-17
# 4  5  7.56825e-01  2.43175e-01  1.25818e-16  4.14561e-17  1.65305e-17
#
#   truncated_eigenvalue_1 truncated_eigenvalue_2 truncated_eigenvalue_3  \
# 0            7.70782e-01                0.0e+00                0.0e+00
# 1            7.56825e-01            2.43175e-01                0.0e+00
# 2            7.56825e-01            2.43175e-01            1.06744e-16
# 3            7.56825e-01            2.43175e-01            5.88099e-17
# 4            7.56825e-01            2.43175e-01            1.25818e-16
#
#   truncated_eigenvalue_4 truncated_eigenvalue_5 lower_tqfi        h_z
# 0                0.0e+00                0.0e+00  6.791e+00  2.841e+00
# 1                0.0e+00                0.0e+00  9.112e+00  2.802e+00
# 2                0.0e+00                0.0e+00  9.112e+00  2.802e+00
# 3            3.96896e-17                0.0e+00  9.112e+00  2.802e+00
# 4            4.14561e-17            1.65305e-17  9.112e+00  2.802e+00

# %%
df["lower_tqfi"]
# Out:
# 0    6.791e+00
# 1    9.112e+00
# 2    9.112e+00
# 3    9.112e+00
# 4    9.112e+00
# Name: lower_tqfi, dtype: object

# %%
results = [qfi_optimization.get_best_lower_bound(n, a_x, delta, m, trace_out_index, derivative_delta, h_z_bounds=h_z_bounds)
           for m in range(1, m_max)]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 results = [qfi_optimization.get_best_lower_bound(n, a_x, delta, m, trace_out_index, derivative_delta, h_z_bounds=h_z_bounds)
#       2            for m in range(1, m_max)]
#
# File ~/Dev/space/QFI/qfi_optimization.py:67, in get_best_lower_bound(n, a_x, delta, m, trace_out_index, derivative_delta, h_z_bounds)
#      62 lower_bound_for_h_z = get_lower_bound(
#      63     n, a_x, delta, m, trace_out_index, derivative_delta
#      64 )
#      66 # Step 1: Optimize within bounds
# ---> 67 res = minimize_scalar(
#      68     lambda h_z: -lower_bound_for_h_z(h_z),
#      69     bounds=h_z_bounds,
#      70     method="bounded",
#      71 )
#      73 # Restore the sign for the optimizer's result
#      74 res.fun = -res.fun
#
# File ~/miniforge3/envs/space/lib/python3.12/site-packages/scipy/optimize/_minimize.py:966, in minimize_scalar(fun, bracket, bounds, args, method, tol, options)
#     963     if bounds is None:
#     964         raise ValueError('The `bounds` parameter is mandatory for '
#     965                          'method `bounded`.')
# --> 966     res = _minimize_scalar_bounded(fun, bounds, args, **options)
#     967 elif meth == 'golden':
#     968     res = _recover_from_bracket_error(_minimize_scalar_golden,
#     969                                       fun, bracket, args, **options)
#
# File ~/miniforge3/envs/space/lib/python3.12/site-packages/scipy/optimize/_optimize.py:2321, in _minimize_scalar_bounded(func, bounds, args, xatol, maxiter, disp, **unknown_options)
#    2319 si = np.sign(rat) + (rat == 0)
#    2320 x = xf + si * np.maximum(np.abs(rat), tol1)
# -> 2321 fu = func(x, *args)
#    2322 num += 1
#    2323 fmin_data = (num, x, fu)
#
# File ~/Dev/space/QFI/qfi_optimization.py:68, in get_best_lower_bound.<locals>.<lambda>(h_z)
#      62 lower_bound_for_h_z = get_lower_bound(
#      63     n, a_x, delta, m, trace_out_index, derivative_delta
#      64 )
#      66 # Step 1: Optimize within bounds
#      67 res = minimize_scalar(
# ---> 68     lambda h_z: -lower_bound_for_h_z(h_z),
#      69     bounds=h_z_bounds,
#      70     method="bounded",
#      71 )
#      73 # Restore the sign for the optimizer's result
#      74 res.fun = -res.fun
#
# File ~/Dev/space/QFI/qfi_optimization.py:31, in get_lower_bound.<locals>.lower_bound_for_h_z(h_z)
#      21 def lower_bound_for_h_z(h_z):
#      22     """returns the lower bound for a given h_z.
#      23
#      24     Args:
#    (...)
#      28         float : value for the lower bound at h_z
#      29     """
#      30     return np.real(
# ---> 31         pipeline_v100.simulation(
#      32             n=n,
#      33             a_x=a_x,
#      34             h_z=h_z,
#      35             delta=delta,
#      36             trace_out_index=trace_out_index,
#      37             derivative_delta=derivative_delta,
#      38             m=m,
#      39             DEBUG=True,
#      40         )["lower_tqfi"]
#      41     )
#
# File ~/Dev/space/QFI/pipeline_v100.py:49, in simulation(n, a_x, h_z, delta, m, DEBUG, trace_out_index, derivative_delta)
#      29 model = density_generator.IsingQuantumState(
#      30     n=n, a_x=a_x, h_z=h_z, trace_out_index=trace_out_index
#      31 )
#      32 # rho_0, rho_delta_0 = model.generate_density_matrices_with_perturbation(delta=delta)
#      33
#      34 # plot_state_city(rho)
#    (...)
#      46 # rho = rho_qutip.ptrace(sel=list(range(n - 1))).full()
#      47 # rho_delta = rho_delta_qutip.ptrace(sel=list(range(n - 1))).full()
# ---> 49 rho, rho_delta = model.generate_mixed(delta=delta)
#      51 ## Getting results from classical QFI
#      52 results = classicalQFI.compute_tqfi_bounds(
#      53     rho=rho, rho_delta=rho_delta, m=m, delta=delta
#      54 )
#
# File ~/Dev/space/QFI/density_generator.py:187, in IsingQuantumState.generate_mixed(self, delta)
#     174 """
#     175 Generates a mixed state by tracing out one qubit.
#     176
#    (...)
#     183     rho_delta (numpy.ndarray): Perturbed reduced density matrix.
#     184 """
#     186 # Generate perturbed density matrices
# --> 187 rho_0, rho_delta_0 = self.generate_density_matrices_with_perturbation(
#     188     delta=delta
#     189 )
#     191 # Convert to QuTiP objects (ensuring correct dimensions)
#     192 rho_qutip = qutip.Qobj(rho_0, dims=[[2] * self.n, [2] * self.n])
#
# File ~/Dev/space/QFI/density_generator.py:150, in IsingQuantumState.generate_density_matrices_with_perturbation(self, delta)
#     148 original_hz = self.h_z
#     149 self.h_z += delta
# --> 150 rho_perturbed = self.generate_density_matrix()
#     152 # Restore original h_z
#     153 self.h_z = original_hz
#
# File ~/Dev/space/QFI/density_generator.py:120, in IsingQuantumState.generate_density_matrix(self)
#     117 H = self._construct_hamiltonian()
#     119 # Unitary evolution operator
# --> 120 U = expm(-1j * H)
#     122 # Define initial state |0...0> in computational basis
#     123 # For n qubits, |0...0> is dimension 2^n with a 1 in the first component.
#     124 dim = 2**self.n
#
# File ~/miniforge3/envs/space/lib/python3.12/site-packages/scipy/linalg/_matfuncs.py:328, in expm(A)
#     325 if s != 0:  # scaling needed
#     326     Am[:4] *= [[[2**(-s)]], [[4**(-s)]], [[16**(-s)]], [[64**(-s)]]]
# --> 328 pade_UV_calc(Am, n, m)
#     329 eAw = Am[0]
#     331 if s != 0:  # squaring needed
#
# KeyboardInterrupt:

# %%
max_lower_bounds = [r.fun for r in results]
plt.plot(max_lower_bounds)

plt.grid(True, linestyle="--", alpha=0.6)  # Subtle grid for readability
